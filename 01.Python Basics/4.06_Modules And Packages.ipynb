# %% [markdown]
# # Modules

# %% [raw]
# 1.Modules refer to file containing Python statements (e.g abc.py) and defnitions.Where abc is module
#
# 2. Used to break down large programs into small manageable and organized files.Furthermore ,modules provide reusabilty of code.
#
# 3.We can define our most used function in module and import it , instaed of compying their defnitions into different programs.

# %% [markdown]
# # How to Impoprt Modules

# %%
import example #import example module
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import example
#
# ModuleNotFoundError: No module named 'example'

# %% [markdown]
# # Python has alot of modules availble
# https://docs.python.org/3/py-modindex.html

# %% [markdown]
# # Examples

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
import math as m
print(m.pi)
# Out:
# 3.141592653589793

# %%
from datetime import datetime
#import datetime
current_datetime=datetime.now()
print(current_datetime)
# Out:
# 2023-05-05 15:17:29.187592

# %%
#import everything
from math import *
print("value of Pi is :" + str(pi))
# Out:
# value of Pi is :3.141592653589793

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
print(math.add.__doc__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print(math.add.__doc__)
#
# AttributeError: module 'math' has no attribute 'add'

# %% [markdown]
# # PACKAGES

# %% [raw]
# it is the way of structuring pythons modules namespace by using "dotted module names"
#
# IMPORTANT:
# A directory must contain a file named init.py in order for python to consider it as package.
#
# init.py file can be left empty but we generally  place the initilization code for that package in this file.

# %% [markdown]
# ![Capture3.JPG](attachment:Capture3.JPG)

# %%
# to load specific Module -->open.py

import Game.Image.open

#import Package.SubPackage.Module
