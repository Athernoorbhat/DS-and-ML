# %% [markdown]
# # Histogram ,PDF

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#load data set
iris=pd.read_csv("iris.csv")
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # 1-D Scatter

# %%
#.loc() to crete subset on specific conditions

iris_Setosa = iris.loc[iris["variety"] == "Setosa"]
iris_Virginica = iris.loc[iris["variety"] == "Virginica"]
iris_Versicolor = iris.loc[iris["variety"] == "Versicolor"]
#print(iris_Setosa["sepal.length"])

sns.set_style("whitegrid")
plt.plot(iris_Setosa["petal.length"], np.zeros_like(iris_Setosa["petal.length"]))
#x axix=petal.length and y axis =0
plt.plot(iris_Virginica["petal.length"], np.zeros_like(iris_Virginica["petal.length"]))
plt.plot(iris_Versicolor["petal.length"], np.zeros_like(iris_Versicolor["petal.length"]))

sns.set_style("whitegrid")
sns.FacetGrid(iris, hue="variety", height=5) \
    .map(sns.distplot, "petal.length") \
    .add_legend()

#density distribution

plt.show()
# Out:
# C:\Users\noora\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\noora\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# # Observations

# %% [markdown]
# 1.Histogram  with line is (PDF)
#
# 2.prob distribution function is smooth form of histogram

# %%
#.loc() to crete subset on specific conditions
iris_Setosa = iris.loc[iris["variety"] == "Setosa"]
iris_Virginica = iris.loc[iris["variety"] == "Virginica"]
iris_Versicolor = iris.loc[iris["variety"] == "Versicolor"]
#print(iris_Setosa["sepal.length"])

plt.plot(iris_Setosa["petal.length"], np.zeros_like(iris_Setosa["petal.length"]),"o")
#x axix=petal.length and y axis =0

plt.plot(iris_Virginica["petal.length"], np.zeros_like(iris_Virginica["petal.length"]),"o")
plt.plot(iris_Versicolor["petal.length"], np.zeros_like(iris_Versicolor["petal.length"]),"o")

sns.FacetGrid(iris, hue="variety", height=5) \
    .map(sns.histplot, "petal.length", kde=True,stat="density",kde_kws=dict(cut=3)) \
    .add_legend()
#histogram plot
#distribution plot not used now so use

#kernel density estimate

plt.show()

# %% [markdown]
# # UniVariate Analysis

# %% [raw]
# Which among 4 sepal.length', 'sepal.width', 'petal.length', 'petal.width is most imp to us

# %%
#Ist case petal length
sns.set_style("whitegrid")
sns.FacetGrid(iris, hue="variety", height=5) \
    .map(sns.histplot, "petal.length", kde=True,stat="density",kde_kws=dict(cut=3)) \
    .add_legend()
#distribution plot
#kde=kernel density estimate line
#stat="density" to take density on axis  else takes count

plt.show();

# %%
#2nd case petal width
sns.set_style("whitegrid")
sns.FacetGrid(iris, hue="variety", height=5) \
    .map(sns.histplot, "petal.width", kde=True,stat="density",kde_kws=dict(cut=3)) \
    .add_legend()
plt.show();

# %%
#3rd case sepal length
sns.set_style("whitegrid")
sns.FacetGrid(iris, hue="variety", height=5) \
    .map(sns.histplot, "sepal.length", kde=True,stat="density",kde_kws=dict(cut=3)) \
    .add_legend()
plt.show();

# %%
#4th case sepal width
sns.set_style("whitegrid")
sns.FacetGrid(iris, hue="variety", height=5) \
    .map(sns.histplot, "sepal.width", kde=True,stat="density",kde_kws=dict(cut=3)) \
    .add_legend()
plt.show();

# %% [markdown]
# # The far the distribution from one another the better is the case

# %% [markdown]
# # CDF

# %% [raw]
# https://www.graduatetutor.com/statistics-tutor/probability-density-function-pdf-and-cumulative-distribution-function-cdf/

# %% [raw]
# CDF=area under curve of pdf(Integrate)
# d/dx(CDF)=PDF

# %%
#automatically assigned to the variables counts and bin_edges
counts,bin_edges=np.histogram(iris_Setosa['petal.length'],bins=10,density=True)
#divide the range of values in the data into 10 equally spaced bins

#compute PDF
pdf=counts/(sum(counts))
print(pdf);
print(bin_edges)


#compute CDF
cdf=np.cumsum(pdf) #commulative sum
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

#bin_edges[1:] is a slicing operation that selects all elements of the bin_edges array 
#from index 1 onwards. This is done to exclude the first element 
#because it typically represents the leftmost edge of the first bin

plt.show();
# Out:
# [0.02 0.02 0.04 0.14 0.26 0.26 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
#Setosa
counts,bin_edges=np.histogram(iris_Setosa['petal.length'],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

#Virginica
counts,bin_edges=np.histogram(iris_Virginica['petal.length'],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf=np.cumsum(pdf) #commulative sum
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

#Virsicolor
counts,bin_edges=np.histogram(iris_Versicolor['petal.length'],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf=np.cumsum(pdf) #commulative sum
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)



plt.show();
# Out:
# [0.02 0.02 0.04 0.14 0.26 0.26 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]
# [0.02 0.1  0.24 0.08 0.18 0.16 0.1  0.04 0.02 0.06]
# [4.5  4.74 4.98 5.22 5.46 5.7  5.94 6.18 6.42 6.66 6.9 ]
# [0.02 0.04 0.06 0.04 0.16 0.14 0.12 0.2  0.14 0.08]
# [3.   3.21 3.42 3.63 3.84 4.05 4.26 4.47 4.68 4.89 5.1 ]

# %% [markdown]
# # Observation

# %% [raw]
# X-axis = petal length
# Setosa --> petal lenth <2 is 100 % Setosa
# Virginica--> petal length is >3 and <=5 is 95%(correct) + 5%(wrong) Virginica
# Virsicolor-->petal length is >5  is  10%(wrong) + 90%(correct)  Virsicolor

# %%
import numpy as np    
hist, bin_edges = np.histogram([1, 1, 2, 2, 2, 2, 3], bins = range(5))

print(hist)
#[0 2 4 1]
#Below, hist indicates that there are 0 items in bin #0,
#2 in bin #1, 4 in bin #3, 1 in bin #4.


print (bin_edges)
#[0 1 2 3 4]

#bin_edges indicates that bin #0 is the interval [0,1),
#bin #1 is [1,2), ..., bin #3 is [3,4).
# Out:
# [0 2 4 1]
# [0 1 2 3 4]

# %%
import numpy as np    
hist, bin_edges = np.histogram([1, 1, 2, 2, 2, 2, 3], bins =2)

print(hist)
print (bin_edges)
# Out:
# [2 5]
# [1. 2. 3.]

# %% [raw]
# The hist variable stores an array containing the counts of values that fall into each bin. In this case, there are 2 occurrences of the value 1 and 5 occurrences of the value 2.

# %% [raw]
# The bin_edges variable stores an array representing the edges of the bins. In this example, it contains three values [1. 2. 3.], indicating that the bin intervals are [1, 2) and [2, 3].

# %%
import numpy as np    
count, bin_edges = np.histogram([1, 1, 2, 2, 2, 3, 3, 3, 3], bins =3)

print(count)
print (bin_edges)
# Out:
# [2 3 4]
# [1.         1.66666667 2.33333333 3.        ]

# %%
Univariate Analysi-->PDF,CDF,Box PLot,Violin PLot
# Out:
#   Cell In[14], line 1
#     Univariate Analysi-->PDF,CDF,Box PLot,Violin PLot
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Multivariate Probability Density (MPD) ,Contour Plot

# %% [raw]
# two Univariate distribution of petal length and petal width to give contour

# %%
#2-D Density Plot,contour plot
sns.jointplot(data=iris_Setosa,kind='kde',x='petal.length',y='petal.width',fill=True, thresh=0, cmap='Blues')
plt.show();
