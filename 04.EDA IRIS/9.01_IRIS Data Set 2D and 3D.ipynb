# %% [markdown]
# # Plotting for Exploratory Data Analysis

# %% [raw]
# Iris Data Set
#
# --> Classify the flower into 3 catagories/Classes(Dependent Variable) on the basis on Features/Variable(Independent Variable) like petal (length and width) and petal (length and width)
#
# https://en.wikipedia.org/wiki/Iris_flower_data_set
# --> simple data set
#
# -->1D Vector is Scaler

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#load data set
iris=pd.read_csv("iris.csv")
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
#shape --how many data points and features 150rows x5 columns 
print(iris.shape)
# Out:
# (150, 5)

# %%
#what are the column names in our dataset?
print(iris.columns)
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
#4D data
iris.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
iris.variety.value_counts()
#or
#iris["variety"].value_counts()

#balnced data set
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64

# %%
iris["variety"].describe()
# Out:
# count        150
# unique         3
# top       Setosa
# freq          50
# Name: variety, dtype: object

# %% [markdown]
# # 2D Scatter Plot

# %%
#2-D scatter plot
#always understand the axis:labels and scale.
iris.plot(kind='scatter',x='sepal.length',y='sepal.width')

plt.show()
#plot(kind='bar')
#plot(kind='hist')

#no much from it
#what if we color code
#start point is not (0,0)
#see the range of x-axis and y-axis

# %% [markdown]
# # Observations
# 1.not much sense as such
#
# 2.starting point is not(0,0) eather approx (4,1)

# %% [raw]
# 2-D scatter plot with FacetGrid

# %% [raw]
# A FacetGrid is a multi-axes grid with subplots visualizing the distribution of variables of a dataset and the relationship between multiple variables.

# %%
#2-D scatter plot with color code
#sns --> seaborn
sns.set_style("whitegrid") #gives write grid structure
sns.FacetGrid(iris, hue="variety" ,height=5) \
    .map(plt.scatter,'sepal.length','sepal.width')\
    .add_legend();
#hue=variety--> means color it on variety height kitne graph ki
#.map(plt.scatter,'x=sepal.length','y=sepal.width') 
#legend--> gives names

plt.show()

# %% [markdown]
# # Observations
# 1.Sepal length and sepal width feature can distinguish setosa flower from other
# 2.Sperating Versicolor and virginica is much harder as they are overlapping

# %% [markdown]
# # 3-D Scatter Plot
#
# https://plotly.com/python/3d-scatter-plots/
#
# 1.Cannot visualize higer dimensional pattern in 3D and 4D.
#
# 2.Only possible to view 2D pattern, simple trick of pairplot comes to help

# %% [raw]
# 3-D Scatter Plot with pairplot

# %%
#pairwise scatter plot: Pair-Plot
plt.close();
sns.set_style("whitegrid") #gives write grid structure
sns.pairplot(iris, hue="variety" ,height=5);
plt.show()

# %% [markdown]
# # Observations

# %% [raw]
# 1.all 4 independent elem --> sepal.length', 'sepal.width', 'petal.length', 'petal.width
#
# 4 C 2 = 6 plots
# 10 C 2= 100 Plots
#
# 2.Ignore diagonal elem for now
#
#
# 3.
# #(1,1) = sepal length(x) and sepal length(y)
# #(1,2) = sepal width(x) and sepal length(y)
# #(1,3) = petal length(x) and sepal length(y)
# #(1,4) = petal width(x) and sepal length(y)
#
# 4.
# #(x,y) mirror image (y,x)
# #(3,4) mirror image (4,3)
#
# 5.Focus on top Diagonal elements.
#     Setosa Varity is distinguised by graph of top diag except(1,2)
#     #graph(3,4)
#     #if pl<=2 & pw <=1
#     #then setosa
#     similarly for versicolor and verginica

# %% [markdown]
# # Limitations of Pair Plots

# %% [raw]
# 4 elem
# 4 C 2 = 6 plots easy to handle
#
# 10 C 2= 100 Plots so complex

# %% [markdown]
# # Bivaraite Analysis --> Pair Plot , Scatter Plot

# %% [markdown]
# # Multivariate Analysis --> 3D Plot

# %% [markdown]
# # Multivariate Probability Density (MPD) ,Contour Plot

# %%
iris_Setosa = iris.loc[iris["variety"] == "Setosa"]
iris_Virginica = iris.loc[iris["variety"] == "Virginica"]
iris_Versicolor = iris.loc[iris["variety"] == "Versicolor"]

# %%
#Density Plot,contour plot
sns.jointplot(data=iris_Setosa,kind='kde',x='petal.length',y='petal.width',fill=True, thresh=0, cmap='Blues')
plt.show();

#'scatter', 'hist', 'hex', 'kde', 'reg', 'resid'

# %%
#3D  Density Plot,contour plot
sns.jointplot(data=iris,hue='variety',kind='kde',x='petal.length',y='petal.width')
plt.show();
